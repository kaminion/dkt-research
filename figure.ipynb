# %%
import os 
import pickle
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

model_name = 'dkvmn+'

abs_path = f'.{os.path.sep}ckpts{os.path.sep}{model_name}{os.path.sep}'
path = f'ASSIST2012{os.path.sep}'
cnt_file_name = 'q_cnts.pkl'
acc_file_name = 'q_accs.pkl'
cnt_file = None
acc_file = None

full_path = os.path.join(os.path.join(abs_path, path), cnt_file_name)
with open(full_path, "rb") as f:
    cnt_file = pickle.load(f)
full_path = os.path.join(os.path.join(abs_path, path), acc_file_name)
with open(full_path, "rb") as f:
    acc_file = pickle.load(f)

# %%
question_tags = []
accs = []
cnts = []

for ((cnt_k, cnt_v), (acc_k, acc_v)) in zip(cnt_file.items(), acc_file.items()):
    question_tags.append(f"{cnt_k} ({cnt_v})")
    cnts.append(cnt_v)
    accs.append(acc_v)
question_tags
# Out:
# ['103 (11)',
#  '80 (14)',
#  '74 (9)',
#  '59 (17)',
#  '163 (13)',
#  '6 (2)',
#  '91 (12)',
#  '46 (12)',
#  '97 (22)',
#  '11 (6)',
#  '25 (1)',
#  '172 (39)',
#  '15 (6)',
#  '47 (1)',
#  '167 (1)',
#  '23 (1)',
#  '93 (1)',
#  '100 (1)',
#  '13 (2)',
#  '16 (11)',
#  '92 (1)',
#  '48 (1)',
#  '1 (1)',
#  '168 (1)',
#  '37 (1)',
#  '94 (1)',
#  '2 (1)',
#  '45 (15)',
#  '129 (1)',
#  '26 (6)',
#  '5 (17)',
#  '96 (14)',
#  '30 (1)',
#  '31 (1)',
#  '39 (10)',
#  '156 (5)',
#  '0 (2)',
#  '29 (1)',
#  '44 (1)',
#  '136 (3)',
#  '56 (1)',
#  '106 (6)',
#  '150 (9)',
#  '104 (9)',
#  '140 (9)',
#  '87 (11)',
#  '55 (28)',
#  '85 (14)',
#  '154 (1)',
#  '4 (16)',
#  '105 (3)',
#  '127 (6)',
#  '71 (1)',
#  '9 (4)',
#  '132 (3)',
#  '130 (8)',
#  '184 (4)',
#  '113 (4)',
#  '118 (6)',
#  '189 (22)',
#  '125 (4)',
#  '107 (3)',
#  '40 (2)',
#  '122 (1)',
#  '116 (2)',
#  '19 (5)',
#  '193 (12)',
#  '76 (3)',
#  '77 (4)',
#  '186 (4)',
#  '68 (2)',
#  '126 (1)',
#  '10 (1)',
#  '34 (5)',
#  '21 (1)',
#  '12 (8)',
#  '153 (4)',
#  '192 (2)',
#  '64 (1)',
#  '161 (5)',
#  '160 (1)',
#  '194 (1)',
#  '75 (2)',
#  '35 (9)',
#  '123 (25)',
#  '195 (2)',
#  '99 (5)',
#  '41 (3)',
#  '187 (2)',
#  '67 (1)',
#  '137 (4)']

# %%
plt.rcParams['figure.figsize'] = [10, 23] # 2009 - 13

x = np.arange(len(accs))
bar_labels = plt.barh(x, accs, color="red", alpha=0.5)
plt.xlabel('Accuracy', fontsize=15, fontweight="bold")
plt.ylabel('Question Tags (count)', fontsize=15, fontweight="bold")
plt.yticks(x, question_tags, fontsize=15)

plt.bar_label(bar_labels)

plt.show()
